# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

people = pd.read_csv('people.csv')
people
# Out:
#       name   gpa  height  total friends       shoes       sport
# 0   dakota  3.15      72            307    converse  basketball
# 1   hayden  3.50      68            335  flip-flops      tennis
# 2  charlie  1.10      61             34  flip-flops    baseball
# 3   kamryn  2.18      66            200    converse      soccer
# 4  emerson  3.06      65            213    converse      soccer
# 5   jessie  2.41      61            202  flip-flops  basketball
# 6   sawyer  2.96      67            314  flip-flops      tennis
# 7   london  3.98      64            436  flip-flops      soccer

# %% [markdown]
# https://www.geeksforgeeks.org/how-to-set-a-seaborn-chart-figure-size/

# %%
sns.lmplot(data=people, x='gpa', y='total friends', hue='shoes')

# %%
wine_reviews = pd.read_csv("wine-reviews.csv")
wine_reviews
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
best_wines = wine_reviews.loc[wine_reviews.points == 100].value_counts("country")
best_wines
# Out:
# country
# France       8
# Italy        4
# US           4
# Portugal     2
# Australia    1
# dtype: int64

# %%
sns.barplot(x=best_wines.index, y=best_wines)
# Out:
# <AxesSubplot:xlabel='country'>
